# %%
#DATA Ingestion

# doc structure
# !pip install langchain-core
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata = {
        'source': 'example.txt',
        'page': 1,
        'author': 'Sakthivel',
        'date_created': '05/05/2026'
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'page': 1, 'author': 'Sakthivel', 'date_created': '05/05/2026'}, page_content='This is the content of the document.')
